# %% [markdown]
# # <h1><center>GOI Financial Budget Analysis - 2021</center></h1>

# %% [markdown]
# ![Ministry_of_Finance_India.svg.png](attachment:Ministry_of_Finance_India.svg.png)

# %% [markdown]
# <h2>GOI-Budget 2021 synopsis</h2>
# <ul>
#     India's 2021-2022 budget, presented by the government on February 1, 2021, focuses on boosting infrastructure and investment in the country's rural and agricultural sectors. The budget includes a major allocation of funds for building and upgrading highways, ports, airports, and railways, as well as for the expansion of rural electrification and digital connectivity. The government also announced various schemes to provide employment to rural workers. Overall, the budget is geared towards boosting economic growth and creating jobs, particularly in the country's rural areas.
#
# </ul>

# %% [markdown]
# ### Importing libraries and Analysing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('D:\Data Analysis\Files\Data_web\Website-data-master\India_budget_2021.csv')
df.head()
# Out:
#                    Department /Ministry  Fund allotted(in ₹crores)
# 0               MINISTRY OF AGRICULTURE                  131531.19
# 1           DEPARTMENT OF ATOMIC ENERGY                   18264.89
# 2            MINISTRY OF AYURVEDA, YOGA                    2970.30
# 3  MINISTRY OF CHEMICALS AND FERTILISER                   80714.94
# 4            MINISTRY OF CIVIL AVIATION                    3224.67

# %%
df.shape
# Out:
# (57, 2)

# %%
df.size
# Out:
# 114

# %%
df.describe().T
# Out:
#                            count         mean            std    min  \
# Fund allotted(in ₹crores)   56.0  124401.2725  497430.315964  39.25
#
#                                  25%       50%        75%         max
# Fund allotted(in ₹crores)  2079.6225  6638.935  58199.005  3483235.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Department /Ministry       56 non-null     object
#  1   Fund allotted(in ₹crores)  56 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.0+ KB

# %%
df.columns
# Out:
# Index(['Department /Ministry', 'Fund allotted(in ₹crores)'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Department /Ministry         1
# Fund allotted(in ₹crores)    1
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
df=df.iloc[[0,3,6,8,11,14,15,18,21,23,24,27,29,32,36,39,41,42,43,44,53],:]
dr={'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)':721080.64}
df=df.append(dr,ignore_index=True)
df
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                MINISTRY OF CHEMICALS AND FERTILISER
# 2                   MINISTRY OF COMMERCE AND INDUSTRY
# 3                        MINISTRY OF CONSUMER AFFAIRS
# 4                                 MINISTRY OF DEFENCE
# 5                               MINISTRY OF EDUCATION
# 6   MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# 7                                 MINISTRY OF FINANCE
# 8               MINISTRY OF HEALTH AND FAMILY WELFARE
# 9                            MINISTRY OF HOME AFFAIRS
# 10              MINISTRY OF HOUSING AND URBAN AFFAIRS
# 11                  MINISTRY OF LABOUR AND EMPLOYMENT
# 12    MINISTRY OF MICRO, SMALL AND MEDIUM ENTERPRISES
# 13               MINISTRY OF NEW AND RENEWABLE ENERGY
# 14              MINISTRY OF PETROLEUM AND NATURAL GAS
# 15                                  MINISTRY OF POWER
# ...

# %%
b=sns.barplot(x='Fund allotted(in ₹crores)',y='Department /Ministry',data=df)
b.axes.set_title("Ministry Vs Fund_Allocation",fontsize=20)
b.set_xlabel("Fund allotted(in ₹crores)",fontsize=10)
b.set_ylabel("Department /Ministry",fontsize=10)
b.tick_params(labelsize=8)
plt.show()

# %%
df.plot.kde()
plt.ylabel('Max Fund allotted(in ₹crores)')
plt.show()

# %%
data= df["Fund allotted(in ₹crores)"]
labels = df["Department /Ministry"]
plt.figure(figsize=(28,28))
plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=18)
plt.title("Distribution of Budget", fontsize=30)
plt.show()

# %% [markdown]
# The Analysis depicts that Ministry of Finance has highest allocation with 35.3%.
# Followed by Ministry of Defence with allocation of 12.2% & Ministry of Consumers Affairs 6.5%.
